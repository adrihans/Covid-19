# %% [markdown]
# # Façon d'indexer les phrases

# %%
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument

# %%
model=Doc2Vec(vector_size=200)
corpus = [
     'This is the first document',
     'This is the second second document',
     'And the third one',]

# %%
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(corpus)]

# %%
#model_dbow = Doc2Vec(dm=0, vector_size=300, negative=5, hs=0, min_count=2, sample = 0, workers=cores)
model.build_vocab(documents)

# %%
model.train(documents,total_examples=model.corpus_count, epochs=2)

# %%
#len([model.infer_vector(s) for s in (["second", "document"],["third","document"])])

model.infer_vector(["second", "document"]).shape
# Out:
# (200,)

# %% [markdown]
# # Notebook de test

# %% [markdown]
# Premiers essais
#
# **Using that for preprocessing data:**
# https://allenai.github.io/scispacy/
#
# Very good medium article :
#
# https://medium.com/@adriensieg/text-similarities-da019229c894
#
# **To DO**
# - Lemmatization
# - STOP-WORDS
# - TF-IDF
# - t-SNE ?
# - Visualizing data
#
# - Gérer les '-PRON-'
#
#
# Information retrieval : https://medium.com/@shubhamagarwal328/information-retrieval-in-natural-language-processing-part-1-96c9a62fdb5f
#
# Information extraction :
# https://www.analyticsvidhya.com/blog/2019/09/introduction-information-extraction-python-spacy/
#
# https://towardsdatascience.com/deep-learning-for-specific-information-extraction-from-unstructured-texts-12c5b9dceada
#
#
# Information retrieval in medical papers :
# https://www.acl-bg.org/proceedings/2017/RANLP_W4%202017/pdf/BioNLP001.pdf
#
#
# Question answering :
# https://towardsdatascience.com/nlp-building-a-question-answering-model-ed0529a68c54
#
# https://rajpurkar.github.io/SQuAD-explorer/
#
# Automatic question answering :
#
# https://towardsdatascience.com/automatic-question-answering-ac7593432842
#
#
# Information retrieval with code :
#
# https://medium.com/voice-tech-podcast/information-retrieval-using-boolean-query-in-python-e0ea9bf57f76
#
#
# https://www.tutorialspoint.com/natural_language_processing/natural_language_processing_information_retrieval.htm
#
#
# Knowledge Graph :
#
# https://medium.com/analytics-vidhya/knowledge-graph-a-powerful-data-science-technique-to-mine-information-from-text-with-python-f8bfd217accc

# %% [markdown]
# ## Ideas :
#
# **Firstly:**
#
#
#
# - TFIDF cosine similarity to find the most accurate sentences
# - Retrieving of the original document (to not have the sentences in an unreadable way)
#
# **Then** :
#
# Indexing the sentences, then perform preprocessing/tfidf to find the indexes of the sentences which are relevant.
#
# Picking a few from their scores (the 3/5 best ones, or the ones above a similarity score given a threshold, or both options combined together)
#
# **To perform a better visualization of the documents** :
# - PCA / LDA or t-SNE
# - K-means to make clusters
# - Chi-2 scores to see the most relevant words for each cluster
#
# **We could even make a button next to an article to see its position compared to others**

# %% [markdown]
# ## Loading packages

# %%
#Dealing with the DataFrame: 
import pandas as pd
#Dealing with the visualization: 
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import HTML
#Preprocessing the text
import spacy
import re

import numpy as np
#Type:
import string

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.cluster import KMeans


import nltk
from normalise import normalise
from nltk.tokenize import word_tokenize

#Saving and Loading variables:
import pickle


#Representation and Dimensionnality reduction:
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

#Dashboarding with bokeh:
from bokeh.plotting import figure 
from bokeh.io import output_notebook, show
output_notebook()


#To find the associated grams to a cluster:
from sklearn.feature_selection import chi2
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="21150">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Loading and exploring data :

# %%
df_covid= pd.read_csv('cord19_df.csv')

# %%
df_covid.head()
# Out:
#                                    paper_id  \
# 0  0015023cc06b5362d332b3baf348d11567ca2fbb
# 1  004f0f8bb66cf446678dc13cf2701feec4f36d76
# 2  00d16927588fb04d4be0e6b269fc02f0d3c2aa7b
# 3  0139ea4ca580af99b602c6435368e7fdbefacb03
# 4  013d9d1cba8a54d5d3718c229b812d7cf91b6c89
#
#                                            body_text source_x  \
# 0  VP3, and VP0 (which is further processed to VP...  biorxiv
# 1  The 2019-nCoV epidemic has spread across China...  medrxiv
# 2  Infectious bronchitis (IB), which is caused by...  biorxiv
# 3  Nipah is an infectious negative-sense single-s...  biorxiv
# 4  In December 2019, a cluster of patients with p...  medrxiv
#
#                                                title  \
# 0  The RNA pseudoknots in foot-and-mouth disease ...
# 1  Healthcare-resource-adjusted vulnerabilities t...
# 2  Real-time, MinION-based, amplicon sequencing f...
# 3  A Combined Evidence Approach to Prioritize Nip...
# 4  Assessing spread risk of Wuhan novel coronavir...
#
#                            doi pmcid  pubmed_id  license  \
# 0    10.1101/2020.01.10.901801   NaN        NaN  biorxiv
# 1  10.1101/2020.02.11.20022111   NaN        NaN  medrvix
# 2               10.1101/634600   NaN        NaN  biorxiv
# 3    10.1101/2020.03.12.977918   NaN        NaN  biorxiv
# 4  10.1101/2020.02.04.20020479   NaN        NaN  medrvix
#
#                                             abstract publish_time  \
# 0  The positive stranded RNA genomes of picornavi...   2020-01-11
# 1  We integrate the human movement and healthcare...   2020-02-12
# 2  Infectious bronchitis (IB) causes significant ...   2019-05-10
# 3  AbstractBackgroundNipah Virus (NiV) came into ...   2020-03-12
# 4  Background: A novel coronavirus (2019-nCoV) em...   2020-02-05
#
#                                              authors journal  \
# 0  Ward, J. C. J.; Lasecka-Dykes, L.; Neil, C.; A...     NaN
# 1  Hanchu Zhou; Jianan Yang; Kaichen Tang; Qingpe...     NaN
# 2  Butt, S. L.; Erwood, E. C.; Zhang, J.; Sellers...     NaN
# 3  Nishi Kumari; Ayush Upadhyay; Kishan Kalia; Ra...     NaN
# 4  Shengjie Lai; Isaac Bogoch; Nick Ruktanonchai;...     NaN
#
#    Microsoft Academic Paper ID WHO #Covidence has_full_text   full_text_file  \
# 0                          NaN            NaN          True  biorxiv_medrxiv
# 1                          NaN            NaN          True  biorxiv_medrxiv
# 2                          NaN            NaN          True  biorxiv_medrxiv
# 3                          NaN            NaN          True  biorxiv_medrxiv
# 4                          NaN            NaN          True  biorxiv_medrxiv
#
#    publish_year                                           link
# 0          2020    http://dx.doi.org/10.1101/2020.01.10.901801
# 1          2020  http://dx.doi.org/10.1101/2020.02.11.20022111
# 2          2019               http://dx.doi.org/10.1101/634600
# 3          2020    http://dx.doi.org/10.1101/2020.03.12.977918
# 4          2020  http://dx.doi.org/10.1101/2020.02.04.20020479

# %% [markdown]
# **Les premières 15000 en attendant d'avoir tout fait:**

# %%
df_body_text_15000=pd.read_csv('cord19_df_pre_full_text_file_15000.csv')

# %%
df_body_text_15000.head()
# Out:
#                                      body_text_15000
# 0  vp3 vp0 process vp2 vp4 virus assembly 6 p2 64...
# 1  2019-ncov epidemic spread china 24 country 1 3...
# 2  infectious bronchitis ib cause infectious bron...
# 3  nipah infectious negative sense single strand ...
# 4  december 2019 cluster patient pneumonia unknow...

# %% [markdown]
# On transforme donc `df_covid` pour avoir la version voulue, avec seulement les 15000 premiers articles:

# %%
df_covid=df_covid[:15000]

# %%
df_preprocessed_covid=df_covid[:15000]

# %%
df_preprocessed_covid.body_text =df_body_text_15000.body_text_15000

# %% [markdown]
# ### General informations :

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 18 columns):
# paper_id                       15000 non-null object
# body_text                      15000 non-null object
# source_x                       14141 non-null object
# title                          14124 non-null object
# doi                            14061 non-null object
# pmcid                          8904 non-null object
# pubmed_id                      11428 non-null float64
# license                        14141 non-null object
# abstract                       13647 non-null object
# publish_time                   14080 non-null object
# authors                        13939 non-null object
# journal                        13252 non-null object
# Microsoft Academic Paper ID    116 non-null float64
# WHO #Covidence                 158 non-null object
# has_full_text                  14141 non-null object
# full_text_file                 14141 non-null object
# publish_year                   15000 non-null int64
# link                           14061 non-null object
# dtypes: float64(2), int64(1), object(15)
# memory usage: 2.1+ MB

# %%
df_covid.describe()
# Out:
#           pubmed_id  Microsoft Academic Paper ID  publish_year
# count  1.142800e+04                 1.160000e+02  15000.000000
# mean   2.475201e+07                 2.786688e+09   1889.711333
# std    6.023832e+06                 4.631567e+08    483.360950
# min    2.360400e+04                 1.776631e+08     -1.000000
# 25%    2.190218e+07                 2.813374e+09   2010.000000
# 50%    2.603989e+07                 3.004338e+09   2015.000000
# 75%    2.932507e+07                 3.005576e+09   2018.000000
# max    3.215896e+07                 3.006672e+09   2020.000000

# %% [markdown]
# #### Years of publication

# %%
fig = plt.figure(figsize=(15,5))
sns.countplot(df_covid.publish_year)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# '-1' is when the year is unknown

# %% [markdown]
# #### Has full text ?

# %%
fig=plt.figure(figsize=(15,5))
sns.countplot(df_covid.has_full_text)

# %% [markdown]
# We have the full text for every articles

# %% [markdown]
# #### Length of the different parts :

# %% [markdown]
# ##### Length of the body text of the articles

# %%
Len=[]
for i in df_covid.body_text:
    Len.append(len(i))

# %%
plt.figure(figsize=(15,5))
plt.hist(Len,bins=50)
plt.show()

# %%
Len=np.array(Len)
len(Len[Len>1500000])
# Out:
# 6

# %% [markdown]
# Taking the first one :

# %%
Len[Len>1000000][0]
# Out:
# 1153996

# %%
d={'lengths':Len}
Lengths=pd.DataFrame(data=d)

# %%
Lengths[Lengths>1500000].dropna()
# Out:
#          lengths
# 16328  1722585.0
# 16583  1634577.0
# 16818  1566439.0
# 23678  1529937.0
# 24582  1549213.0
# 28883  1676463.0

# %%
df_covid['body_text'].iloc[6830:6832]
# Out:
# 6830    Intraspecific interactions, or interactions be...
# 6831    purpose of this study was to demonstrate the e...
# Name: body_text, dtype: object

# %%
len(df_covid.body_text.iloc[6831])
# Out:
# 1153996

# %%
df_covid.body_text.shape
# Out:
# (29327,)

# %%
np.max(Len)
# Out:
# 1722585

# %% [markdown]
# ## Preprocessing data :

# %% [markdown]
# To make data clearer, we are going to use :
# - lemmatization
# - the removing of stop words

# %% [markdown]
# ### Using a custom function

# %% [markdown]
# We use this: https://www.kaggle.com/balatmak/text-preprocessing-steps-and-universal-pipeline
#
# AND (same thing) :
#
# https://towardsdatascience.com/text-preprocessing-steps-and-universal-pipeline-94233cb6725a

# %% [markdown]
# On adpate le pipeline ci-dessus pour faire du fonctionnel:

# %%
global spacy_nlp
spacy_nlp = spacy.load('en_core_web_sm')
def normalize(text):
    # some issues in normalise package
    try:
        return ' '.join(normalise(text,tokenizer=word_tokenize,verbose=False))
    except:
        return text
def remove_punct(doc):
    return [t for t in doc if t.text not in string.punctuation]
def remove_stop_words(doc):
    return [t for t in doc if not t.is_stop]
def lemmatize(doc):
    return ' '.join([t.lemma_ for t in doc])
    
def preprocessing_part(text):
    normalized_text=normalize(text).lower()
    doc=spacy_nlp(normalized_text)
    removed_punct=remove_punct(doc)
    removed_stop_words=remove_stop_words(removed_punct)
    return lemmatize(removed_stop_words)

# %% [markdown]
# #### Applying to the CORD-19 dataset:

# %% [markdown]
# This was already applied in a .py file, using multithreading to increase speed and efficience.

# %% [markdown]
# ## Representation  of DATA :

# %% [markdown]
# To find cosine similarity measure between documents, we use this : https://markhneedham.com/blog/2016/07/27/scitkit-learn-tfidf-and-cosine-similarity-for-computer-science-papers/

# %% [markdown]
# #### Function to find similar documents from its index:

# %%
def find_similar_from_index(tfidf_matrix, index, top_n = 5):
    """
    Function find_similar to find the similar documents of one given document, given its index in the corpus. 
    
    @Inputs : 
    tfidf_matrix : matrix returned by the tfidf transformation of the entire corpus
    index : the index of the document
    top_n : the number of articles similar to be shown
    
    @Outputs : 
    
    """
    cosine_similarities = linear_kernel(tfidf_matrix[index:index+1], tfidf_matrix).flatten()
    related_docs_indices = [i for i in cosine_similarities.argsort()[::-1] if i != index]
    return [(index, cosine_similarities[index]) for index in related_docs_indices][0:top_n]

# %% [markdown]
# #### Function to find documents similar to a given query, and making the transformation :

# %%
def find_documents_from_query(tfidf_matrix, tfidf_query, top_n=5):
    """
    Function find_documents_from_query, which computes the top_n most relevent articles given the tfidf representation
    of the query
    
    @Inputs:
    - tfidf_matrix, the tfidf matrix representation of the entire set of articles
    - tfidf_query, the tfidf vector representation of the query
    - top_n = 5, the number of documents to find
    @Outputs: 
    indexes_scores, the index of each top_n article in the DataFrame, and the associated cosine_similarity score
    """
    #We calculate the cosine similarity between the query and each document:
    cosine_similarities = linear_kernel(tfidf_query, tfidf_matrix).flatten()
    #We sort the documents from the similarit to the query :
    related_docs_indices = [i for i in cosine_similarities.argsort()[::-1]]
    #We retrieve the top n documents most similar to the given query :
    indexes_scores = [(index, cosine_similarities[index]) for index in related_docs_indices][0:top_n]
    return indexes_scores

# %% [markdown]
# #### Function to export the sentences most relevent from each article :

# %% [markdown]
# For this purpose, we need to :
# - index each sentences of the given articles
# - perform TF-IDF on the set of sentences
# - Compare the query with each sentence using cosine similarity
#
# For the last task, we can easily use the function `find_similar`, just like before.
#
# If we perform reduction on the documents to plot each documents with the distance to the other, we could also to the same with the sentences.
#
# - Then, we show the relevent sentences, given a criteria :
#     - We can use a threshold on the similarity score
#     - We can also use a number of sentences to show, but this could end up showing sentences completely out of context
#     - Therefore, I think we can use both.
#
# **Warning** :
#
# We must index the sentences before making any transformation to the text !!!
#
# To avoid empty sentences (with the lemmatisation)  We can show either a number of characters or sentences before and after the one chosen.
#
# We can also verify that two sentences are not one after the other.

# %% [markdown]
# ##### Function to index the sentences of an article:

# %%
def sentence_indexing(article):
    """
    Function sentence_indexing made to index the sentences of an article
    
    @Inputs: 
    article, the text of the article
    
    @Outputs:
    df_sentences, a pandas DataFrame, with a single column 'sentences', corresponding to each sentences of the article
                    Obviously, the indexing is then performed directly in the pandas DataFrame.
    """
    #We split the article for each '.' encountered, this gives every sentences of the text, which we then store in the
    #Pandas DataFrame 'df_sentences'.
    #We also verify that the sentences are not empty (because of a typo or because of the lemmatization)
    df_sentences=pd.DataFrame({'sentences': [sentence for sentence in article.split('.') if sentence !='']})
    return df_sentences

# %% [markdown]
# ##### Function to find the sentences most relevant for each article found :

# %%
def index_relevant_sentences(tfidf, df_article, tfidf_query):
    """
    Function relevant_sentences, which computes for a given query the most relevant sentences inside an article.
    
    @Inputs: 
    tfidf, the tfidf model
    df_article, the article
    tfidf_query, the given query, transformed after tfidf
    
    @Outputs : 
    index_score, the index and the score of the most relevant sentences (sorted)
    """
    #We take the sentences of the article:
    df_sentences = sentence_indexing(df_article)
    #We must preprocessed the sentences:
    df_preprocessed_sentences=df_sentences['sentences'].astype(str).apply(preprocessing_part)
    #We transform the sentences with tfidf:
    article_sentences_tfidf = tfidf.transform(df_preprocessed_sentences)
    #We find the most relevant articles given the query, using find_document:
    index_scores = find_documents_from_query(article_sentences_tfidf, tfidf_query)
    return index_scores

# %% [markdown]
# ##### Function to transform the query :

# %%
def transform_query(tfidf, query):
    """
    Function transform_query, which takes the tfidf model and a query, to preprocess it and transform it in a usable form
    @Inputs: 
    tfidf, the tfidf model, fit on the entire corpus
    query, the given str query 
    
    @Outputs: 
    tfidf_query, the transformed query, after cleaning, preprocessing, lemmatization and tfidf transformation    
    """
    preprocessed_query = preprocessing_part(query)
    tfidf_query = tfidf.transform([preprocessed_query]).toarray()
    return tfidf_query

# %% [markdown]
# ##### Function to transform the entire text:

# %%
def transform_text(df_preprocessed_covid, column='body_text'):
    """
    Function transform_textn fitting the tfidf transformation and applying it to transform the articles
    @Inputs: 
    df_preprocessed_covid
    @Outputs: 
    tfidf, the tfidf model
    tfidf_matrix, the tfidf matrix of the set of articles
    """
    df_preprocessed_covid[column] = df_preprocessed_covid[column].fillna(' ')
    # Initializing TFIDF :
    tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1,1), max_features=10000)
    #Defining the features needed :
    tfidf_matrix = tfidf.fit_transform(df_preprocessed_covid[column]).toarray()
    return tfidf, tfidf_matrix

# %% [markdown]
# ##### Executing tfidf and saving / loading the results

# %%
#tfidf, tfidf_matrix = transform_text(df_preprocessed_covid, column='body_text')
#Saving:
#with open('tfidf_model_matrix.pickle', 'wb') as f:
#    pickle.dump([tfidf, tfidf_matrix], f)

#Loading:
with open('tfidf_model_matrix.pickle', 'rb') as f:
    tfidf, tfidf_matrix = pickle.load(f)

# %% [markdown]
# ##### Final function, taking a query, transforming it, returning the most relevant articles and the most relevent sentences inside those articles

# %%
def find_answers(df_covid, df_preprocessed_covid, query,tfidf=tfidf,tfidf_matrix=tfidf_matrix, column='body_text',top_n_sentences=5, top_n_articles=5):
    """
    Function find_answers to find the most relevent sentences inside the most relevant articles 
    @Inputs:
    - df_covid, the DataFrame associated with the plain untransformed articles
    - df_preprocessed_covid, the DataFrame with the articles preprocessed (would be very long to perform this on each
    call of this function)
    - query, str, the plain query, to be transformed
    
    
    -tfidf
    -tfidf_matrix
    
    
    - column, 
    - top_n_sentences : the number of sentences to select
    - top_n_articles : the number of articles to select
    @Outputs:
    - index_score_articles_sentences, a DataFrame, containing the indexes of the articles and the sentences of the
    articles, and the associated scores by cosine similarity
    """
    #Firstly, we compute empty lists to store indexes and scores:
    L_index_articles, L_index_sentences, L_scores_articles, L_scores_sentences= [],[],[],[]
    #We transform by tfidf the preprocessed dataset, selecting the needed column
    #tfidf, tfidf_matrix = transform_text(df_preprocessed_covid, column)
    #We transform the query : 
    tfidf_query=transform_query(tfidf, query)
    #We want to find the most relevant articles for this query : 
    #We compute the indexes of the relevant articles and their associated cosine similarity score
    indexes_scores_articles = find_documents_from_query(tfidf_matrix, tfidf_query, top_n=5)
    #Since we have the indexes, we can have the articles, and find the sentences most relevent inside each article: 
    for index_article, score_article in indexes_scores_articles:
        #Here, since we need to index the sentences of the articles, we take the df_covid, not preprocessed, DataFrame
        index_score_sentences=index_relevant_sentences(tfidf,df_covid.iloc[index_article][column], tfidf_query)       
        for index_sentence, score_sentence in index_score_sentences:
            #We store the wanted data in the associated lists:
            L_index_articles.append(index_article)
            L_index_sentences.append(index_sentence)
            L_scores_articles.append(score_article)
            L_scores_sentences.append(score_sentence)
    #Finally, we compute the DataFrame we want to return 
    d={'index_acrticle' : L_index_articles , 'score_article': L_scores_articles, 'index_sentence':  L_index_sentences,
       'score_sentence':L_scores_sentences } 
    index_score_articles_sentences=pd.DataFrame(data=d)
    return index_score_articles_sentences

# %%
query='Persistence of virus on surfaces of different materials (e,g., copper, stainless steel, plastic).'

# %%
query2='Range of incubation periods for the disease in humans (and how this varies across age and health status) and how long individuals are contagious, even after recovery'

# %%
query3='Persistence and stability on a multitude of substrates and sources (e.g., nasal discharge, sputum, urine, fecal matter, blood).'

# %%
# %time index_score_articles_sentences=find_answers(df_covid, df_preprocessed_covid, query2, column='body_text',top_n_sentences=5, top_n_articles=5)
#index_score_articles_sentences
# Out:
# Wall time: 22.7 s

# %% [markdown]
# Timing:

# %%
# %time tfidf_query=transform_query(tfidf, query)
# Out:
# Wall time: 23.9 ms

# %% [markdown]
# Sur find_documents:

# %%
# %time indexes_scores_articles = find_documents_from_query(tfidf_matrix, tfidf_query, top_n=5)
# Out:
# Wall time: 4.49 s

# %%
#We calculate the cosine similarity between the query and each document:
# %time cosine_similarities = linear_kernel(tfidf_query, tfidf_matrix).flatten()
# Out:
# Wall time: 4.59 s

# %% [markdown]
# **Il faudrait changer la façon de trouver des réponses.**
#
# Et utiliser une autre fonction que linear_kernel

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# %time cosine_similarity(tfidf_query, tfidf_matrix).flatten()
# Out:
# Wall time: 6.24 s
# array([0.00608443, 0.        , 0.00538111, ..., 0.00527128, 0.00587295,
#        0.00657489])

# %%
from timeit import default_timer as timer



column='body_text'


#Firstly, we compute empty lists to store indexes and scores:
L_index_articles, L_index_sentences, L_scores_articles, L_scores_sentences= [],[],[],[]
#We transform by tfidf the preprocessed dataset, selecting the needed column
#tfidf, tfidf_matrix = transform_text(df_preprocessed_covid, column)
#We transform the query : 
# %time tfidf_query=transform_query(tfidf, query)
#We want to find the most relevant articles for this query : 
#We compute the indexes of the relevant articles and their associated cosine similarity score
# %time indexes_scores_articles = find_documents_from_query(tfidf_matrix, tfidf_query, top_n=5)
#Since we have the indexes, we can have the articles, and find the sentences most relevent inside each article: 


start = timer()
for index_article, score_article in indexes_scores_articles:
    #Here, since we need to index the sentences of the articles, we take the df_covid, not preprocessed, DataFrame
    index_score_sentences=index_relevant_sentences(tfidf,df_covid.iloc[index_article][column], tfidf_query)       
    for index_sentence, score_sentence in index_score_sentences:
        #We store the wanted data in the associated lists:
        L_index_articles.append(index_article)
        L_index_sentences.append(index_sentence)
        L_scores_articles.append(score_article)
        L_scores_sentences.append(score_sentence)
#Finally, we compute the DataFrame we want to return 
d={'index_acrticle' : L_index_articles , 'score_article': L_scores_articles, 'index_sentence':  L_index_sentences,
   'score_sentence':L_scores_sentences } 
index_score_articles_sentences=pd.DataFrame(data=d)
end = timer()
print(end - start)
# Out:
# Wall time: 18.9 ms
# Wall time: 4.59 s
# 14.815023999995901

# %% [markdown]
# **PREPROCESSING DANS INDEX_RELEVANT_SENTENCES**

# %% [markdown]
# #### Function to export the results in a good and simple way:

# %% [markdown]
# What we want here is :
# - the link to article
# - the title
# - the authors
# - the source
# - the sentences relevant
# - the similarity scores with the query from cosine similarity
# - the 2/3 most relevant sentences in the entire set.

# %%
def compute_articles_sentences(index_score_articles_sentences, df_covid, h):
    """
    Function compute_articles_sentences which permits to store information about the most relevent articles 
    and their associated relevent sentences """
    
    
    for index_article in index_score_articles_sentences['index_acrticle'].unique(): 
        #We compute the score of the article: 
        score_article=index_score_articles_sentences[index_score_articles_sentences['index_acrticle']==index_article].score_article.iloc[0]
        #We compte the information about the article from the df_covid DataFrame with its associated index:
        article=df_covid.iloc[index_article]
        #Title of the article:
        title=str(article.title)
        #Link of the article:
        link=str(article.link)
        authors=str(article.authors)
        #We plot the general information about the article : 
        h+='<br/><a href="'+link+'" target="_blank">'+title+'</a>, by '+ authors +',  (Similarity Score: ' + "{:.2f}".format(score_article) + ')' 
        
        #We need to index the sentences of the article: 
        df_sentences=sentence_indexing(article.body_text)
        s=index_score_articles_sentences[index_score_articles_sentences['index_acrticle']==index_article]
        index_sentences=s['index_sentence']
        for index_sentence in index_sentences:
            sentence=df_sentences.iloc[index_sentence].sentences
            score_sentence=s[s['index_sentence']==index_sentence]['score_sentence'].iloc[0]
            h+='<ul> <li>' + sentence+ '. (Similarity score: '+ '{:.2f}'.format(score_sentence) +')</li></ul>'
    return h

# %%
def compute_whole_answer(index_score_articles_sentences, df_covid, query, n_sentences=2):
    """
    Function compute_whole_answer to compute the entire response to a query.
    @Inputs:
    -index_score_articles_sentences
    -df_covid
    -query
    -n_sentences=2
    @Output:
    -h
    """
    h='<h3>Responses to the query : "<i>'+query+'</i>"</h3>'
    #Fisrtly, we compute the two most relevent sentences:
    h+='<h4> Most relevent sentences found : </h4>'
    #Computing them by sorting on the sentences scores:
    best_sentences=index_score_articles_sentences.sort_values(by=['score_sentence'], ascending=False)[:n_sentences]
    for index, b_sent in best_sentences.iterrows():   
        index_article=b_sent['index_acrticle'].astype(int)
        article=df_covid.iloc[index_article]
        df_sentences=sentence_indexing(article.body_text)
        index_sentence=b_sent['index_sentence'].astype(int)
        score_sentence=b_sent['score_sentence']
        sentence=df_sentences.iloc[index_sentence].sentences
        h+='<ul><li>'+sentence+ '. (Similarity score: '+ '{:.2f}'.format(score_sentence) +')</li></ul>'   
    h+='<h4> Most relevent articles and the associated sentences : </h4>'
    h=compute_articles_sentences(index_score_articles_sentences, df_covid, h)
    return h

# %%
h=compute_whole_answer(index_score_articles_sentences, df_covid, query3)
display(HTML(h))
# Out:
# <h3>Responses to the query : "<i>Persistence and stability on a multitude of substrates and sources (e.g., nasal discharge, sputum, urine, fecal matter, blood).</i>"</h3><h4> Most relevent sentences found : </h4><ul><li>
# A total of 4 surface materials were evaluated including stainless steel, aluminum, plastic, and galvanized steel. (Similarity score: 0.70)</li></ul><ul><li> galvanized steel, stainless steel, aluminum, and plastic). (Similarity score: 0.67)</li></ul><h4> Most relevent articles and the associated sentences : </h4><br/><a href="http://dx.doi.org/10.3390/ma11122479" target="_blank">Copper Alloy Touch Surfaces in Healthcare Facilities: An Effective Solution to Prevent Bacterial Spreading</a>, by Colin, Marius; Klingelschmitt, Flora; Charpentier, Emilie; Josse, Jérôme; Kanagaratnam, Lukshe; De Champs, Christophe; Gangloff, Sophie C.,  (Similarity Score: 0.24)<ul> <li> Here, we highlighted that, after three years of normal use in healthcare facilities, the copper handles maintain their activity against this pathogen, with a reduction superior to 90% for most of the tested copper door handles, as compared to the residual burden on glass and stainless steel door handles. (Similarity score: 0.47)</li></ul><ul> <li> In vitro tests were also performed on unused copper door handles, stainless steel door handles, and glass slides, to compare the residual bacterial burden after two hours of contact (Figure 4 ). (Similarity score: 0.45)</li></ul><ul> <li> Glass slides (Ghäasel, Dutscher, Brumath, France) and stainless steel door handles (Trenois Decamps, Wasquehal, France) were used as control surfaces. (Similarity score: 0.44)</li></ul><ul> <li> No significant difference was observed in the distribution of the residual burden that was recovered from glass slides or stainless steel door handles. (Similarity score: 0.41)</li></ul><ul> <li> Working on the aging of the copper surface could bring new insight to further increase the antimicrobial activity of the copper alloys and to develop copper surfaces that completely sustain this activity over years of use. (Similarity score: 0.38)</li></ul><br/><a href="http://dx.doi.org/10.1371/journal.pone.0027932" target="_blank">Survival of Influenza A(H1N1) on Materials Found in Households: Implications for Infection Control</a>, by Greatorex, Jane S.; Digard, Paul; Curran, Martin D.; Moynihan, Robert; Wensley, Harrison; Wreghitt, Tim; Varsani, Harsha; Garcia, Fayna; Enstone, Joanne; Nguyen-Van-Tam, Jonathan S.,  (Similarity Score: 0.21)<ul> <li> Metals have been demonstrated to have low levels of anti viral activity [25] [26] [27] ; and stainless steel has previously been demonstrated to support influenza virus viability for longer than that of copper [28] . (Similarity score: 0.60)</li></ul><ul> <li> The only material (other than the control tissue culture dish) for which even low amounts of viable virus could be detected at 9 h was stainless steel. (Similarity score: 0.54)</li></ul><ul> <li>
# As observed in other studies, we found that stainless steel supported the viability of influenza viruses longer than other tested metals. (Similarity score: 0.52)</li></ul><ul> <li> Confirmation of these results raises questions about the use of stainless steel in healthcare and daycare settings in particular. (Similarity score: 0.51)</li></ul><ul> <li> In 1982, widely cited work by Bean et al showed that both influenza A and B, directly applied to stainless steel surfaces or hard plastic, could survive for 24-48 hours, and be transferred, from there to hands, for 24 hours; survival was much shorter on porous materials such as paper and cotton (8-12 hours) , with transferability to hands for only 15 minutes [10] . (Similarity score: 0.43)</li></ul><br/><a href="http://dx.doi.org/10.1186/s40813-017-0064-3" target="_blank">Survival of porcine epidemic diarrhea virus (PEDV) in thermally treated feed ingredients and on surfaces</a>, by Trudeau, Michaela P.; Verma, Harsha; Urriola, Pedro E.; Sampedro, Fernando; Shurson, Gerald C.; Goyal, Sagar M.,  (Similarity Score: 0.21)<ul> <li>
# A total of 4 surface materials were evaluated including stainless steel, aluminum, plastic, and galvanized steel. (Similarity score: 0.70)</li></ul><ul> <li> galvanized steel, stainless steel, aluminum, and plastic). (Similarity score: 0.67)</li></ul><ul> <li>3 log on all surfaces except for stainless steel, in which only a 0. (Similarity score: 0.66)</li></ul><ul> <li>
# The PEDV inoculation solution (40 μL) was applied to the center of a sample of stainless steel, aluminum, plastic, or galvanized steel. (Similarity score: 0.57)</li></ul><ul> <li> This virus has been reported to survive for up to 36 h on stainless steel, but the initial concentration of virus in this study was not reported [22] . (Similarity score: 0.57)</li></ul><br/><a href="http://dx.doi.org/10.1016/j.ajic.2017.07.014" target="_blank">Isolation and identification of human coronavirus 229E from frequently touched environmental surfaces of a university classroom that is cleaned daily</a>, by Bonny, Tania S.; Yezli, Saber; Lednicky, John A.,  (Similarity Score: 0.20)<ul> <li> Surfaces chosen for sampling in this study were (1) seat-backs made of hard polyvinylchloride, (2) laminate desktops, (3) a wooden podium, and (4) a stainless steel doorknob. (Similarity score: 0.49)</li></ul><ul> <li> Briefly, 20 μL aliquots (3 replicates per day, over a 7-day testing period) containing 2 × 10 4 plaque forming units of virus were spotted and spread over the surface of sterile 1 cm 2 hard plastic, glass, and stainless steel coupons. (Similarity score: 0.49)</li></ul><ul> <li> From a public health perspective, a better choice might be brass instead of stainless steel doorknobs because brass has been reported to be deleterious for CoV-229E; however, quick inactivation on brass may not occur for other viruses. (Similarity score: 0.40)</li></ul><ul> <li> Virus survival was monitored, with viable counts of viruses extruded off the different surfaces determined by plaque assay. (Similarity score: 0.10)</li></ul><ul> <li> Desktops and the doorknob were the most commonly contaminated surfaces ( Table 1 ). (Similarity score: 0.08)</li></ul><br/><a href="http://dx.doi.org/10.1186/1471-2334-13-177" target="_blank">Inactivation of an enterovirus by airborne disinfectants</a>, by Thevenin, Thomas; Lobert, Pierre-Emmanuel; Hober, Didier,  (Similarity Score: 0.19)<ul> <li> Therefore stainless steel discs, which were used in this study, were relevant to test the efficiency of disinfectants on surfaces. (Similarity score: 0.48)</li></ul><ul> <li>
# In this study, flocked swabs were used to recover viruses on stainless steel discs. (Similarity score: 0.47)</li></ul><ul> <li>
# In a hospital environment, stainless steel is used for door handles, hand and grab rails in toilets. (Similarity score: 0.43)</li></ul><ul> <li> For the first time, the present work demonstrates, that airborne peracetic acid-based disinfectants can inactivate dried poliovirus inocula on stainless steel carrier as well. (Similarity score: 0.37)</li></ul><ul> <li>
# Poliovirus dried on stainless carriers 50 μL of poliovirus inoculum applied in the middle of each stainless steel disc were dried under the airflow of a class II biological safety cabinet at room temperature (20 ±2°C) for 2 h (±15 min). (Similarity score: 0.37)</li></ul>

# %% [markdown]
# ### Word-Embeddings techniques

# %% [markdown]
# ## Defining the tasks:

# %%
task1 = ["Range of incubation periods for the disease in humans (and how this varies across age and health status) and how long individuals are contagious, even after recovery.",
"Prevalence of asymptomatic shedding and transmission (e.g., particularly children).",
"Seasonality of transmission.",
"Physical science of the coronavirus (e.g., charge distribution, adhesion to hydrophilic/phobic surfaces, environmental survival to inform decontamination efforts for affected areas and provide information about viral shedding).",
"Persistence and stability on a multitude of substrates and sources (e.g., nasal discharge, sputum, urine, fecal matter, blood).",
"Persistence of virus on surfaces of different materials (e,g., copper, stainless steel, plastic).",
"Natural history of the virus and shedding of it from an infected person",
"Implementation of diagnostics and products to improve clinical processes",
"Disease models, including animal models for infection, disease and transmission",
"Tools and studies to monitor phenotypic change and potential adaptation of the virus",
"Immune response and immunity",
"Effectiveness of movement control strategies to prevent secondary transmission in health care and community settings",
 "Effectiveness of personal protective equipment (PPE) and its usefulness to reduce risk of transmission in health care and community settings",
"Role of the environment in transmission"]

task2 = ['Data on potential risks factors',
'Smoking, pre-existing pulmonary disease',
'Co-infections (determine whether co-existing respiratory/viral infections make the virus more transmissible or virulent) and other co-morbidities',
'Neonates and pregnant women',
'Socio-economic and behavioral factors to understand the economic impact of the virus and whether there were differences.',
'Transmission dynamics of the virus, including the basic reproductive number, incubation period, serial interval, modes of transmission and environmental factors', 
'Severity of disease, including risk of fatality among symptomatic hospitalized patients, and high-risk patient groups',
'Susceptibility of populations',
'Public health mitigation measures that could be effective for control']

task3 = ['Real-time tracking of whole genomes and a mechanism for coordinating the rapid dissemination of that information to inform the development of diagnostics and therapeutics and to track variations of the virus over time.',
'Access to geographic and temporal diverse sample sets to understand geographic distribution and genomic differences, and determine whether there is more than one strain in circulation. Multi-lateral agreements such as the Nagoya Protocol could be leveraged.',
'Evidence that livestock could be infected (e.g., field surveillance, genetic sequencing, receptor binding) and serve as a reservoir after the epidemic appears to be over.',
'Evidence of whether farmers are infected, and whether farmers could have played a role in the origin.',
'Surveillance of mixed wildlife- livestock farms for SARS-CoV-2 and other coronaviruses in Southeast Asia.',
'Experimental infections to test host range for this pathogen.',
'Animal host(s) and any evidence of continued spill-over to humans',
'Socioeconomic and behavioral risk factors for this spill-over',
'Sustainable risk reduction strategies']

task4 = ["Guidance on ways to scale up NPIs in a more coordinated way (e.g., establish funding, infrastructure and authorities to support real time, authoritative (qualified participants) collaboration with all states to gain consensus on consistent guidance and to mobilize resources to geographic areas where critical shortfalls are identified) to give us time to enhance our health care delivery system capacity to respond to an increase in cases.",
"Rapid design and execution of experiments to examine and compare NPIs currently being implemented. DHS Centers for Excellence could potentially be leveraged to conduct these experiments.",
"Rapid assessment of the likely efficacy of school closures, travel bans, bans on mass gatherings of various sizes, and other social distancing approaches.",
"Methods to control the spread in communities, barriers to compliance and how these vary among different populations..",
"Models of potential interventions to predict costs and benefits that take account of such factors as race, income, disability, age, geographic location, immigration status, housing status, employment status, and health insurance status.",
"Policy changes necessary to enable the compliance of individuals with limited resources and the underserved with NPIs.",
"Research on why people fail to comply with public health advice, even if they want to do so (e.g., social or financial costs may be too high).",
"Research on the economic impact of this or any pandemic. This would include identifying policy and programmatic alternatives that lessen/mitigate risks to critical government services, food distribution and supplies, access to critical household supplies, and access to health diagnoses, treatment, and needed care, regardless of ability to pay."]

task5 = ["Effectiveness of drugs being developed and tried to treat COVID-19 patients. Clinical and bench trials to investigate less common viral inhibitors against COVID-19 such as naproxen, clarithromycin, and minocyclinethat that may exert effects on viral replication.",
"Methods evaluating potential complication of Antibody-Dependent Enhancement (ADE) in vaccine recipients.",
"Exploration of use of best animal models and their predictive value for a human vaccine.",
"Capabilities to discover a therapeutic (not vaccine) for the disease, and clinical effectiveness studies to discover therapeutics, to include antiviral agents.",
"Alternative models to aid decision makers in determining how to prioritize and distribute scarce, newly proven therapeutics as production ramps up. This could include identifying approaches for expanding production capacity to ensure equitable and timely distribution to populations in need.",
"Efforts targeted at a universal coronavirus vaccine.",
"Efforts to develop animal models and standardize challenge studies",
"Efforts to develop prophylaxis clinical studies and prioritize in healthcare workers",
"Approaches to evaluate risk for enhanced disease after vaccination",
"Assays to evaluate vaccine immune response and process development for vaccines, alongside suitable animal models [in conjunction with therapeutics]"]

task6 = ["Efforts to articulate and translate existing ethical principles and standards to salient issues in COVID-2019", 
"Efforts to embed ethics across all thematic areas, engage with novel ethical issues that arise and coordinate to minimize duplication of oversight",
"Efforts to support sustained education, access, and capacity building in the area of ethics",
"Efforts to establish a team at WHO that will be integrated within multidisciplinary research and operational platforms and that will connect with existing and expanded global networks of social sciences.",
"Efforts to develop qualitative assessment frameworks to systematically collect information related to local barriers and enablers for the uptake and adherence to public health measures for prevention and control. This includes the rapid identification of the secondary impacts of these measures. (e.g. use of surgical masks, modification of health seeking behaviors for SRH, school closures)",
"Efforts to identify how the burden of responding to the outbreak and implementing public health measures affects the physical and psychological health of those providing care for Covid-19 patients and identify the immediate needs that must be addressed.",
"Efforts to identify the underlying drivers of fear, anxiety and stigma that fuel misinformation and rumor, particularly through social media."]

task7 = ["How widespread current exposure is to be able to make immediate policy recommendations on mitigation measures. Denominators for testing and a mechanism for rapidly sharing that information, including demographics, to the extent possible. Sampling methods to determine asymptomatic disease (e.g., use of serosurveys (such as convalescent samples) and early detection of disease (e.g., use of screening of neutralizing antibodies such as ELISAs).",
"Efforts to increase capacity on existing diagnostic platforms and tap into existing surveillance platforms.",
"Recruitment, support, and coordination of local expertise and capacity (public, private—commercial, and non-profit, including academic), including legal, ethical, communications, and operational issues.",
"National guidance and guidelines about best practices to states (e.g., how states might leverage universities and private laboratories for testing purposes, communications to public health officials and the public).",
"Development of a point-of-care test (like a rapid influenza test) and rapid bed-side tests, recognizing the tradeoffs between speed, accessibility, and accuracy.",
"Rapid design and execution of targeted surveillance experiments calling for all potential testers using PCR in a defined area to start testing and report to a specific entity. These experiments could aid in collecting longitudinal samples, which are critical to understanding the impact of ad hoc local interventions (which also need to be recorded).",
"Separation of assay development issues from instruments, and the role of the private sector to help quickly migrate assays onto those devices.",
"Efforts to track the evolution of the virus (i.e., genetic drift or mutations) and avoid locking into specific reagents and surveillance/detection schemes.",
"Latency issues and when there is sufficient viral load to detect the pathogen, and understanding of what is needed in terms of biological and environmental sampling.",
"Use of diagnostics such as host response markers (e.g., cytokines) to detect early disease or predict severe disease progression, which would be important to understanding best clinical practice and efficacy of therapeutic interventions.",
"Policies and protocols for screening and testing.",
"Policies to mitigate the effects on supplies associated with mass testing, including swabs and reagents.",
"Technology roadmap for diagnostics.",
"Barriers to developing and scaling up new diagnostic tests (e.g., market forces), how future coalition and accelerator models (e.g., Coalition for Epidemic Preparedness Innovations) could provide critical funding for diagnostics, and opportunities for a streamlined regulatory environment.",
"New platforms and technology (e.g., CRISPR) to improve response times and employ more holistic approaches to COVID-19 and future diseases.",
"Coupling genomics and diagnostic testing on a large scale.",
"Enhance capabilities for rapid sequencing and bioinformatics to target regions of the genome that will allow specificity for a particular variant.",
"Enhance capacity (people, technology, data) for sequencing with advanced analytics for unknown pathogens, and explore capabilities for distinguishing naturally-occurring pathogens from intentional.",
"One Health surveillance of humans and potential sources of future spillover or ongoing exposure for this organism and future pathogens, including both evolutionary hosts (e.g., bats) and transmission hosts (e.g., heavily trafficked and farmed wildlife and domestic food and companion species), inclusive of environmental, demographic, and occupational risk factors."]


task8 = ["Resources to support skilled nursing facilities and long term care facilities.",
"Mobilization of surge medical staff to address shortages in overwhelmed communities",
"Age-adjusted mortality data for Acute Respiratory Distress Syndrome (ARDS) with/without other organ failure – particularly for viral etiologies",
"Extracorporeal membrane oxygenation (ECMO) outcomes data of COVID-19 patients",
"Outcomes data for COVID-19 after mechanical ventilation adjusted for age.",
"Knowledge of the frequency, manifestations, and course of extrapulmonary manifestations of COVID-19, including, but not limited to, possible cardiomyopathy and cardiac arrest.",
"Application of regulatory standards (e.g., EUA, CLIA) and ability to adapt care to crisis standards of care level.",
"Approaches for encouraging and facilitating the production of elastomeric respirators, which can save thousands of N95 masks.",
"Best telemedicine practices, barriers and faciitators, and specific actions to remove/expand them within and across state boundaries.",
"Guidance on the simple things people can do at home to take care of sick people and manage disease.",
"Oral medications that might potentially work.",
"Use of AI in real-time health care delivery to evaluate interventions, risk factors, and outcomes in a way that could not be done manually.",
"Best practices and critical challenges and innovative solutions and technologies in hospital flow and organization, workforce protection, workforce allocation, community-based support resources, payment, and supply chain management to enhance capacity, efficiency, and outcomes.",
"Efforts to define the natural history of disease to inform clinical care, public health interventions, infection prevention control, transmission, and clinical trials",
"Efforts to develop a core clinical outcome set to maximize usability of data across a range of trials",
"Efforts to determine adjunctive and supportive interventions that can improve the clinical outcomes of infected patients (e.g. steroids, high flow oxygen)"]

task9 = ["Methods for coordinating data-gathering with standardized nomenclature.",
"Sharing response information among planners, providers, and others.",
"Understanding and mitigating barriers to information-sharing.",
"How to recruit, support, and coordinate local (non-Federal) expertise and capacity relevant to public health emergency response (public, private, commercial and non-profit, including academic).",
"Integration of federal/state/local public health surveillance systems.",
"Value of investments in baseline public health response infrastructure preparedness",
"Modes of communicating with target high-risk populations (elderly, health care workers).",
"Risk communication and guidelines that are easy to understand and follow (include targeting at risk populations’ families too).",
"Communication that indicates potential risk of disease to all population groups.",
"Misunderstanding around containment and mitigation.",
"Action plan to mitigate gaps and problems of inequity in the Nation’s public health capability, capacity, and funding to ensure all citizens in need are supported and can access information, surveillance, and treatment.",
"Measures to reach marginalized and disadvantaged populations.",
"Data systems and research priorities and agendas incorporate attention to the needs and circumstances of disadvantaged populations and underrepresented minorities.",
"Mitigating threats to incarcerated people from COVID-19, assuring access to information, prevention, diagnosis, and treatment.",
"Understanding coverage policies (barriers and opportunities) related to testing, treatment, and care"]

tasks={'What is known about transmission, incubation, and environmental stability?': task1,
       'What do we know about COVID-19 risk factors?': task2, 
       'What do we know about virus genetics, origin, and evolution?': task3, 
       'What do we know about non-pharmaceutical interventions?': task4,
       'What do we know about vaccines and therapeutics?': task5, 
       'What has been published about ethical and social science considerations?': task6, 
       'What do we know about diagnostics and surveillance?': task7,
       'What has been published about medical care?': task8, 
       'What has been published about information sharing and inter-sectoral collaboration?': task9}

task_name=list(tasks.keys())

# %% [markdown]
# ## Dashboarding:

# %% [markdown]
# **Representation de PCA + kmeans avec Bokeh:**

# %%
#principalDf['abstract']=df_covid.abstract
principalDf['link']=df_covid.link
principalDf['title']=df_covid.title
principalDf['authors']=df_covid.authors
#principalDf.drop(['abstract'], axis=1, inplace=True)

# %%
principalDf['year']=df_covid.publish_year

# %%
principalDf.head()
# Out:
#    principal component 1  principal component 2  \
# 0              -0.072034               0.271200
# 1               0.194787               0.134121
# 2              -0.005433               0.223983
# 3               0.040433               0.134820
# 4               0.267685               0.222711
#
#                                             link  \
# 0    http://dx.doi.org/10.1101/2020.01.10.901801
# 1  http://dx.doi.org/10.1101/2020.02.11.20022111
# 2               http://dx.doi.org/10.1101/634600
# 3    http://dx.doi.org/10.1101/2020.03.12.977918
# 4  http://dx.doi.org/10.1101/2020.02.04.20020479
#
#                                                title  \
# 0  The RNA pseudoknots in foot-and-mouth disease ...
# 1  Healthcare-resource-adjusted vulnerabilities t...
# 2  Real-time, MinION-based, amplicon sequencing f...
# 3  A Combined Evidence Approach to Prioritize Nip...
# 4  Assessing spread risk of Wuhan novel coronavir...
#
#                                              authors  year
# 0  Ward, J. C. J.; Lasecka-Dykes, L.; Neil, C.; A...  2020
# 1  Hanchu Zhou; Jianan Yang; Kaichen Tang; Qingpe...  2020
# 2  Butt, S. L.; Erwood, E. C.; Zhang, J.; Sellers...  2019
# 3  Nishi Kumari; Ayush Upadhyay; Kishan Kalia; Ra...  2020
# 4  Shengjie Lai; Isaac Bogoch; Nick Ruktanonchai;...  2020

# %%
principalDf = pd.concat([principalDf, df_labels], axis = 1)

# %%
principalDf.head()
# Out:
#    principal component 1  principal component 2  \
# 0              -0.072034               0.271200
# 1               0.194787               0.134121
# 2              -0.005433               0.223983
# 3               0.040433               0.134820
# 4               0.267685               0.222711
#
#                                             link  \
# 0    http://dx.doi.org/10.1101/2020.01.10.901801
# 1  http://dx.doi.org/10.1101/2020.02.11.20022111
# 2               http://dx.doi.org/10.1101/634600
# 3    http://dx.doi.org/10.1101/2020.03.12.977918
# 4  http://dx.doi.org/10.1101/2020.02.04.20020479
#
#                                                title  \
# 0  The RNA pseudoknots in foot-and-mouth disease ...
# 1  Healthcare-resource-adjusted vulnerabilities t...
# 2  Real-time, MinION-based, amplicon sequencing f...
# 3  A Combined Evidence Approach to Prioritize Nip...
# 4  Assessing spread risk of Wuhan novel coronavir...
#
#                                              authors  year  cluster
# 0  Ward, J. C. J.; Lasecka-Dykes, L.; Neil, C.; A...  2020        2
# 1  Hanchu Zhou; Jianan Yang; Kaichen Tang; Qingpe...  2020        7
# 2  Butt, S. L.; Erwood, E. C.; Zhang, J.; Sellers...  2019        4
# 3  Nishi Kumari; Ayush Upadhyay; Kishan Kalia; Ra...  2020        5
# 4  Shengjie Lai; Isaac Bogoch; Nick Ruktanonchai;...  2020        2

# %%
from bokeh.io import curdoc
from bokeh.models import Select, Column, RangeSlider, TapTool, OpenURL, Row, Div, Slider, Button,CheckboxButtonGroup, CheckboxGroup

from bokeh.models import AutocompleteInput, TextInput
from bokeh.models import Panel, Tabs

from bokeh.layouts import column
import pandas as pd
from bokeh.palettes import Category10
from bokeh.transform import linear_cmap

def my_covid_app(doc):
    
    
    #We can make a function to indicate that a time consuming function is executing, via a gif in a div for exemple.
    def loading(name_div):
        #Insted of a gif image, we could use:
        #https://codepen.io/widmr/pen/tklqx
        name_div.text="""<img src="images_dashboard/searching_looney_tunes.gif" height="250" width="400">Please be patient</img>"""
    #---------------------------------------------------------------------------------------------------------#
    #---------------------------------------------------------------------------------------------------------#
    #---------------------------First TAB--------------------------------------------------------------------#
    #---------------------------------------------------------------------------------------------------------#
    #---------------------------------------------------------------------------------------------------------#
    
    #We define properly the source of data:
    source = ColumnDataSource(data=principalDf)
    
    #We define what we want to see when the mouse passes over the circle : 
    p = figure(plot_width=600, plot_height=500, 
               tools=["tap", "pan","wheel_zoom","box_zoom","reset"],  title='PCA of the articles, clustering by k-means')

    
    #We need to map the colors :
    # map colors
    lower_cluster=min(principalDf['cluster'])
    higher_cluster=max(principalDf['cluster'])
    map_color = linear_cmap(field_name='cluster', palette=Category10[10], low=lower_cluster, high=higher_cluster)
    
    
    #We define the scatterplot with circle:
    for cluster_number in principalDf.cluster.argsort():
        """
        source=ColumnDataSource(data=principalDf[principalDf['cluster']==cluster_number])
        
        #p.circle('principal component 1', 'principal component 2', source=source,alpha=0.8,
                 muted_color=map_color, muted_alpha=0.2, 
                 legend='cluster', fill_color=map_color, name='articles_rep')
                 
        """
        print(cluster_number)
    
    
    
    
    
    task_selection = Select(title="Task",options=task_name, value='What is known about transmission, incubation, and environmental stability?')
    query_selection= Select(title="Query of the selected task:", 
                            options = list(tasks['What is known about transmission, incubation, and environmental stability?']), 
                            value='Range of incubation periods for the disease in humans (and how this varies across age and health status) and how long individuals are contagious, even after recovery.') 
    number_articles= Slider(title="Number of articles to show", start=0, end=10, step=1, value=5)
    number_sentences= Slider(title="Number of sentences per article to show", start=0, end=10, step=1, value=5)
    
    
    
    
        
    #RangeSlider to select years:
    min_year=min(principalDf['year'])
    max_year=max(principalDf['year'])
    slider_year=RangeSlider(start=min_year, end=max_year, value=(min_year, max_year), 
                            step=1, title = 'Publish year range', width=200)
    
    
    
    """
    # Define a callback function: callback
    def year_range_slider_callback(attr, old, new):
        # Read the current value of the slider: scale
        scale = slider_year.value        
        data=principalDf[principalDf['year'].between(scale[0],scale[1])]
        source.data=ColumnDataSource.from_df(data)    
   """
    
    
    checkbox_year=CheckboxGroup(labels=["Only known years"], active=[0,1], width=150)
    #To update the plot:
    #checkbox_year.on_change('active', update)   

    
    def update_button_year():
        scale = slider_year.value        
        data=principalDf[principalDf['year'].between(scale[0],scale[1])]
        source.data=ColumnDataSource.from_df(data)
    
    validate_button_year=Button(label='Check for the selected years')
    # Attach the year_range_slider_callback to the 'value' property of slider_year
    #slider_year.on_change('value',year_range_slider_callback)
    validate_button_year.on_click(update_button_year)
    
    
    #We define the callback to update the query to the selected task:
    #https://stackoverflow.com/questions/56278118/python-how-to-dynamically-change-options-in-bokeh-select-widget
    def update_query(attr, old, new):
        task_selected = task_selection.value
        query_selection.options = list(tasks[task_selected])
        query_selection.value = list(tasks[task_selected])[0]

        
        
        
        
        
    #We plot the answers to the query:
    #the part "style={'overflow-y':'scroll', 'height':'350px'}" permits to not overflow the figure and the app
    div_html_response = Div(text=query_selection.value, style={'overflow-y':'scroll', 'height':'350px', 'width':'350px'})
      
          
    
    
    
    
    
    
    
    #We define the callback function to update the answer to the selected query:
    def update_answer():
        #We take the value of the query:
        query_selected=query_selection.value
        #We compute the best sentences and documents and the associated index/score
        index_score_articles_sentences=find_answers(df_covid, df_preprocessed_covid, query_selected)
        h=compute_whole_answer(index_score_articles_sentences, df_covid, query_selected)
        div_html_response.text=h
        #div_html_response.text=query_selected
        #We update the representation of the query in the plot:
        update_representation_query()
        
        
    def loading_updating_answer(attr, old, new):
        #To be able to show that the work is in progress, 
        #We use that : https://discourse.bokeh.org/t/show-loading-sign-during-calculations/4410
        #We indicate to the user that the app is searching for results:
        loading(div_html_response)
        curdoc().add_next_tick_callback(update_answer)
        
        
    #We define the behaviour when the query is modified:
    query_selection.on_change('value', loading_updating_answer)
    #We also want that the query is updated when the task is modified.
    #We define the behaviour when the task is modified:
    #We have modified the function update_query accordingly.
    task_selection.on_change('value', update_query)



    
    
    #--------------------------------------------------------------------Plotting the QUERY ----------------------#
    #We plot the query in the graph:
    query_coordinates=principalComponents = PrincipalCA.transform(transform_query(tfidf, query_selection.value))
    [[query_x, query_y]]=query_coordinates
    data_query = {'query_x': [query_x],'query_y': [query_y], 'query' : [query_selection.value]}
    source_rep_query=ColumnDataSource(data=data_query)
    p.circle(x='query_x', y='query_y', size=10,  fill_color="red", legend_label='Query', 
             name='query_rep', source=source_rep_query)

    
    def update_representation_query():
        #We update the coordinates of the query:
        query_coordinates= PrincipalCA.transform(transform_query(tfidf, query_selection.value))
        [[new_query_x, new_query_y]]=query_coordinates
        new_data_query={'query_x': [new_query_x],'query_y': [new_query_y], 'query': [query_selection.value]}
        source_rep_query.data=new_data_query
    
    #-------------------------------------------------------------------------------------------------------------------------#  
    
    
    #Legend behaviour:
    p.legend.location = "top_right"
    p.legend.click_policy="mute"
    
    
    #Hovers (one for the article points, the over for the query)
    #Tooltips for the hover definition on the representation of the articles:
    tooltips_articles = [("Title", "@title"),('Authors', "@authors"),("url", "@link"),]
    #Tooltips for the hover definition on the query:
    tooltips_query=[("Your Query","@query")]
    
    hover_article=HoverTool(names=['articles_rep'], tooltips=tooltips_articles)
    hover_query=HoverTool(names=['query_rep'], tooltips=tooltips_query)
    
    
    p.add_tools(hover_article)
    p.add_tools(hover_query)
    
    
    #We define the link of each glyph as the link column in the DataFrame
    url = "@link"
    taptool = p.select(type=TapTool)
    #We the user taps on a glyph (a circle associated with an article), the url is open
    taptool.callback = OpenURL(url=url)
    
    
    
    #We define the way to plot the different parts of the app:
    #We have the left part with the question-answering
    layout_left=column(task_selection, query_selection, number_articles, number_sentences,div_html_response)
    #We have the right part with the PCA representation and the clustering.
    year_layout=Row(slider_year,validate_button_year)
    layout_right=column(checkbox_year, year_layout, p)
    #We define the entire layout:
    entire_layout1=Row(layout_left,layout_right)
    
    
    
    
    #---------------------------------------------------------------------------------------------------------#
    #---------------------------------------------------------------------------------------------------------#
    #---------------------------SECOND TAB--------------------------------------------------------------------#
    #-------------------------------FREE SEARCH---------------------------------------------------------------#
    #---------------------------------------------------------------------------------------------------------#
    free_search_input = TextInput(value="")
    validation_free_search=Button(label='Search')
    #We define the first results:
    div_results_free_search=Div(text="""Please enter your search in the input bar above and click on 'Search' 
    <br/> The results can be quite long to be obtained so please be patient""", 
        style={'overflow-y':'scroll', 'max_height':'500px', 'width':'900px'})
    
    
    free_visualization_button=Button(label='Show the visualization of your query')
    #We can use the visible property on glyph:
    #https://docs.bokeh.org/en/latest/docs/user_guide/styling.html
    def set_visualization_on_off():
        value=free_visualization_button.label
        if value=='Show the visualization of your query':
            free_visualization_button.label='Hide the visualization of your query'
        else:
            free_visualization_button.label='Show the visualization of your query'
    free_visualization_button.on_click(set_visualization_on_off)
    
    
    
    
    
    
    def update_free_answer():
        #We take the value of the query:
        query=free_search_input.value
        #We compute the best sentences and documents and the associated index/score
        index_score_articles_sentences=find_answers(df_covid, df_preprocessed_covid, query)
        h=compute_whole_answer(index_score_articles_sentences, df_covid, query)
        div_results_free_search.text=h
        
        
    def update_search():
        loading(div_results_free_search)
        curdoc().add_next_tick_callback(update_free_answer)

    
    
    
    
    
    #If the search button is clicked, then the search is performed:
    validation_free_search.on_click(update_search)
    
    
    
    #We define how the tab will render:
    layout_head_search=Row(free_search_input, validation_free_search, free_visualization_button)
    entire_layout2=column(layout_head_search, div_results_free_search)
    #---------------------------------------------------------------------------------------------------------#
    #---------------------------------------------------------------------------------------------------------#
    #---------------------------Third TAB--------------------------------------------------------------------#
    #-----------------------------ABOUT-----------------------------------------------------------------------#
    #---------------------------------------------------------------------------------------------------------#    
    div_about=Div(text="""<h2> About this App </h2>
    This app is part of the CORD-19 Project 
    <br/><h2> About me </h2>
    I am a 22 years old student from France<br/> you can find my linkedIn account here, and my github account here
    <br/> <h2>Thank you very much for your time and consideration regarding this notebook and this application.</h2>
    <br/> <img src="images_dashboard/merci.gif" height="250" width="400"></img>""", width=800)
    
    
    
    
    entire_layout3=column(div_about)
    #---------------------------------------------------------------------------------------------------------#
    #---------------------------------------------------------------------------------------------------------#
    #------------------------------------------Defining the complete app:-------------------------------------#
    #https://docs.bokeh.org/en/latest/docs/reference/models/layouts.html?highlight=tabs#bokeh.models.layouts.Tabs
    #---------------------------------------------------------------------------------------------------------#
    #---------------------------------------------------------------------------------------------------------#
    tab1 = Panel(child=entire_layout1, title="Task responses and Visualization")
    tab2 = Panel(child=entire_layout2, title="Free Search")  
    tab3 = Panel(child=entire_layout3, title="About")
    tabs = Tabs(tabs=[ tab1, tab2, tab3 ])
    doc.add_root(tabs)

# %% [markdown]
# We plot the interactive Bokeh app:
#
#
# using the documentation : https://github.com/bokeh/bokeh/blob/2.0.0/examples/howto/server_embed/notebook_embed.ipynb

# %%
show(my_covid_app)

# %% [markdown]
# # Representation:

# %% [markdown]
# ## Dimensionnality reduction with PCA :

# %% [markdown]
# https://towardsdatascience.com/pca-using-python-scikit-learn-e653f8989e60

# %%
PrincipalCA = TruncatedSVD(n_components=2)
principalComponents=PrincipalCA.fit_transform(tfidf_matrix)
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])

#finalDf = pd.concat([principalDf, y], axis = 1)
fig=plt.figure(figsize=(10,10))
#sns.scatterplot(x=finalDf['principal component 1'], y=finalDf['principal component 2'], hue=finalDf.party, palette="muted")

sns.scatterplot(x=principalDf['principal component 1'], y=principalDf['principal component 2'], palette="muted")
plt.show()

# %% [markdown]
# ### PCA:

# %%
PrincipalCA = PCA(n_components=2)
principalComponents=PrincipalCA.fit_transform(tfidf_matrix)
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])
fig=plt.figure(figsize=(10,10))
sns.scatterplot(x=principalDf['principal component 1'], y=principalDf['principal component 2'], palette="muted")
plt.show()

# %% [markdown]
# ## PCA +  t-SNE ?

# %% [markdown]
# https://towardsdatascience.com/visualising-high-dimensional-datasets-using-pca-and-t-sne-in-python-8ef87e7915b
#
# Reading the sklearn documentation, it is highly recommended to use PCA before t-SNE.
# https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html
#
#
# Predictable t-SNE ?
#
# http://www.xavierdupre.fr/app/mlinsights/helpsphinx/notebooks/predictable_tsne.html

# %%
#We firstly compute a Principal Component Analysis with 50 components
PCA_50 = PCA(n_components=100)
principalComponents50=PCA_50.fit_transform(tfidf_matrix)
#We then compute the t-SNE to have 2 principal components:
tsne_2 = TSNE(n_components=2)
principalComponents = tsne_2.fit_transform(principalComponents50)
#We compute the DataFrame:
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])
fig=plt.figure(figsize=(10,10))
sns.scatterplot(x=principalDf['principal component 1'], y=principalDf['principal component 2'], palette="muted")
plt.show()

# %%
data_labels={'cluster': labels}
df_labels=pd.DataFrame(data=data_labels)

# %% [markdown]
# ### Plotting the results t-SNE/ K-means:

# %%
finalDf = pd.concat([principalDf, df_labels], axis = 1)

# %%
fig=plt.figure(figsize=(15,10))
sns.scatterplot(x=finalDf['principal component 1'], y=finalDf['principal component 2'], 
                hue=finalDf.cluster, palette='Accent', legend='full')
plt.show()

# %% [markdown]
# ## Clustering :

# %% [markdown]
# ### K-means :

# %%
number_clusters = 10
kmeans = KMeans(n_clusters=number_clusters)
labels = kmeans.fit_predict(tfidf_matrix)

# %%
data_labels={'cluster': labels}
df_labels=pd.DataFrame(data=data_labels)

# %% [markdown]
# ### Plotting the results PCA/ K-means:

# %%
finalDf = pd.concat([principalDf, df_labels], axis = 1)

# %%
fig=plt.figure(figsize=(15,10))
sns.scatterplot(x=finalDf['principal component 1'], y=finalDf['principal component 2'], 
                hue=finalDf.cluster, palette='Accent', legend='full')
plt.show()

# %% [markdown]
# ## Function representation :

# %%
def reduction_clustering(tfidf_matrix, number_clusters=10):
    """
    Function reduction_clustering to make both the reduction on a DataFrame and to cluster the data
    We use PCA for the reduction and Kmeans for the clustering part
    
    @Inputs:
    - tfidf_matrix
    - number_clusters
    @Outputs:
    - finalDf, the DataFrame containg the wanted information.
        Column: 'principal component 1', the first coordinate by PCA
                'principal component 2', the second coordinate by PCA
                'cluster', the cluster of the row returned by KMeans
    - PCA, the trained PCA model
    - kmeans, the trained KMeans model
    """
    PrincipalCA = PCA(n_components=2)
    principalComponents=PrincipalCA.fit_transform(tfidf_matrix)
    df_reduction = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])
    kmeans = KMeans(n_clusters=number_clusters)
    labels = kmeans.fit_predict(tfidf_matrix)
    data_labels={'cluster': labels}
    df_labels=pd.DataFrame(data=data_labels)
    finalDf = pd.concat([df_reduction, df_labels], axis = 1)    
    return finalDf, PrincipalCA, kmeans

# %% [markdown]
# Then, we can compute directly the dimensionnality reduction, the clustering algorithm, and the DataFrame associated with the data we want to obtain.

# %%
finalDf, PrincipalCA, kmeans=reduction_clustering(tfidf_matrix)

# %% [markdown]
# ### Taking the most correlated unigrams to get information about each cluster:

# %% [markdown]
# We can help ourselves with that article :
#
# https://towardsdatascience.com/multi-class-text-classification-with-scikit-learn-12f1e60e0a9f
#
# And this scikit-learn documentation :
#
# http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.chi2.html

# %%
def correlations_grams(tfidf_matrix, labels, tfidf, N=2):
    """
    function to get the most correlated n-grams associated with each cluster
    @Inputs:
        - features
        - labels
        - tfidf
        - N, le nombre de N-grammes à afficher
    @Output:
        Corresponding_Grams
    """
    unique_labels=np.unique(labels)
    #We set up the list Corresponding_Grams that we want to return:
    Corresponding_Grams=[]
    for label in unique_labels:
        features_chi2 = chi2(tfidf_matrix, labels == label)
        indices = np.argsort(features_chi2[0])
        feature_names = np.array(tfidf.get_feature_names())[indices]
        unigrams = [v for v in feature_names if len(v.split(' ')) == 1]        
        #We store the results:
        Corresponding_Grams.append(unigrams[-N:])
    return Corresponding_Grams

# %%
def print_corresponding_grams(Corresponding_Grams):
    """
    function print_corresponding_grams to plot the corresponding grams to a label
    @Inputs:
    -Corresponding_Grams
    @Output:
    -None"""
    i=0
    for unigrams in Corresponding_Grams:
        print("For the label : '{}':".format(i))
        print(". Most correlated unigrams:\n   . {}".format('\n   . '.join(unigrams)))
        i+=1
    return None

def associate_corresponding_grams(Corresponding_Grams, df, column_label_name='cluster'):
    """
    Function associate_corresponding_grams which associates the grams most correlated with each cluster
    Please be careful, this function applies the transformation to the DataFrame in input.
    
    @Inputs:
    - Corresponding_Grams
    - df
    - column_label_name
    @Output:
    - df, the DataFrame
    """
    df['label_corresponding_name']=df[column_label_name]
    dictionnary={int(i) : str(Corresponding_Grams[i]) for i in range(len(Corresponding_Grams))}
    df['label_corresponding_name'].replace(dictionnary, inplace=True)
    return df

# %%
Corresponding_Grams=correlations_grams(tfidf_matrix,labels,tfidf, N=10)

# %%
associate_corresponding_grams(Corresponding_Grams, finalDf)
# Out:
# {0: "['apoptosis', 'ifn', 'dcs', 'signaling', 'kinase', 'receptor', 'activate', 'pathway', 'innate', 'activation']", 1: "['ari', 'metapneumovirus', 'hospitalization', 'nasopharyngeal', 'hospitalize', 'child', 'admission', 'rhinovirus', 'hmpv', 'rsv']", 2: "['biorxiv', '2020', 'peer', 'perpetuity', 'medrxiv', 'funder', '1101', 'holder', 'copyright', 'preprint']", 3: "['en', 'dans', 'como', 'sont', 'les', 'por', 'una', 'entre', 'une', 'que']", 4: "['amplicon', 'accession', 'primer', 'sequencing', 'sequence', 'tree', 'contig', 'nucleotide', 'genbank', 'phylogenetic']", 5: "['pdb', 'hydrophobic', 'spectra', 'solvent', 'conformation', 'residue', 'helix', 'nmr', 'atom', 'bond']", 6: "['blot', 'fbs', 'sigma', 'wash', 'dmem', 'transfecte', 'moi', 'plate', 'incubate', 'pbs']", 7: "['respondent', 'political', 'sector', 'professional', 'education', 'service', 'preparedness', 'policy', 'public', 'government']", 8: "['assume', 'parameter', 'simulate', 'assumption', 'spatial', 'mathematical', 'stochastic', 'equation', 'probability', 'simulation']", 9: "['diarrhoea', 'spp', 'biopsy', 'abdominal', 'kg', 'oocyst', 'dairy', 'colostrum', 'calf', 'lesion']"}
#        principal component 1  principal component 2  \
# 0                  -0.072034               0.271200
# 1                   0.194787               0.134121
# 2                  -0.005433               0.223983
# 3                   0.040433               0.134820
# 4                   0.267685               0.222711
# 5                   0.033004               0.163617
# 6                   0.023335               0.247303
# 7                   0.229929               0.122453
# 8                  -0.165714               0.145972
# 9                   0.190506               0.115636
# 10                 -0.168683               0.259460
# 11                 -0.099236               0.243047
# 12                  0.060874               0.294310
# 13                  0.157431               0.324096
# 14                 -0.151531               0.183704
# 15                 -0.115840               0.194954
# 16                  0.230499               0.256246
# 17                  0.054272               0.279057
# 18                  0.049600               0.273466
# 19                  0.210395               0.229079
# 20                 -0.007473               0.223610
# 21                 -0.071745               0.166229
# 22                  0.193959               0.178231
# 23                 -0.045189               0.219957
# 24                  0.178972               0.282805
# 25                  0.216711               0.214761
# 26                 -0.080272               0.273443
# 27                 -0.174359               0.191554
# 28                 -0.182422               0.208714
# 29                 -0.173774               0.014117
# ...                      ...                    ...
# 14970               0.014990              -0.044091
# 14971               0.029384               0.129779
# 14972               0.097116              -0.161598
# 14973              -0.081651               0.064893
# 14974              -0.050261              -0.193198
# 14975              -0.132350              -0.023519
# 14976              -0.143309              -0.074982
# 14977               0.143721              -0.119111
# 14978              -0.001372              -0.094189
# 14979               0.013687              -0.084537
# 14980               0.223670               0.038446
# 14981               0.236337               0.003418
# 14982              -0.019193              -0.122533
# 14983               0.080050              -0.097400
# 14984               0.079966              -0.176903
# 14985               0.278037              -0.010734
# 14986               0.210015              -0.037699
# 14987              -0.155135               0.038121
# 14988               0.244325              -0.040802
# 14989               0.030609              -0.226801
# 14990              -0.148184               0.027911
# 14991              -0.132691               0.102122
# 14992               0.242450               0.015124
# 14993              -0.176202              -0.154990
# 14994               0.252111              -0.014467
# 14995              -0.014052               0.007014
# 14996               0.204395               0.006178
# 14997               0.121882              -0.147812
# 14998               0.088786              -0.023912
# 14999               0.018281               0.037151
#
#                                                     link  \
# 0            http://dx.doi.org/10.1101/2020.01.10.901801
# 1          http://dx.doi.org/10.1101/2020.02.11.20022111
# 2                       http://dx.doi.org/10.1101/634600
# 3            http://dx.doi.org/10.1101/2020.03.12.977918
# 4          http://dx.doi.org/10.1101/2020.02.04.20020479
# 5          http://dx.doi.org/10.1101/2020.02.24.20025437
# 6                       http://dx.doi.org/10.1101/029397
# 7                       http://dx.doi.org/10.1101/230565
# 8                       http://dx.doi.org/10.1101/564427
# 9            http://dx.doi.org/10.1101/2020.01.27.921536
# 10                      http://dx.doi.org/10.1101/661579
# 11                      http://dx.doi.org/10.1101/478040
# 12         http://dx.doi.org/10.1101/2020.02.22.20025460
# 13         http://dx.doi.org/10.1101/2020.03.11.20024901
# 14                      http://dx.doi.org/10.1101/282707
# 15           http://dx.doi.org/10.1101/2020.03.13.991307
# 16         http://dx.doi.org/10.1101/2020.02.12.20022566
# 17           http://dx.doi.org/10.1101/2020.01.10.901728
# 18           http://dx.doi.org/10.1101/2020.01.27.921627
# 19         http://dx.doi.org/10.1101/2020.02.10.20021725
# 20           http://dx.doi.org/10.1101/2020.03.16.993584
# 21           http://dx.doi.org/10.1101/2020.02.29.971093
# 22                      http://dx.doi.org/10.1101/496901
# 23                      http://dx.doi.org/10.1101/185876
# 24                    http://dx.doi.org/10.1101/19008417
# 25         http://dx.doi.org/10.1101/2020.02.21.20026112
# 26           http://dx.doi.org/10.1101/2020.02.23.961912
# 27           http://dx.doi.org/10.1101/2020.01.07.896977
# 28                      http://dx.doi.org/10.1101/442996
# 29           http://dx.doi.org/10.1101/2020.02.26.966143
# ...                                                  ...
# 14970        http://dx.doi.org/10.1016/j.dld.2015.07.008
# 14971     http://dx.doi.org/10.1016/j.watres.2018.03.017
# 14972          http://dx.doi.org/10.1067/mai.2000.108912
# 14973   http://dx.doi.org/10.1016/j.foodchem.2010.03.048
# 14974  http://dx.doi.org/10.1016/B978-012498264-2/500...
# 14975    http://dx.doi.org/10.1016/S2225-4110(16)30070-0
# 14976       http://dx.doi.org/10.1016/j.jaut.2010.05.001
# 14977       http://dx.doi.org/10.1016/j.jrid.2015.11.004
# 14978   http://dx.doi.org/10.1016/j.jviromet.2008.11.007
# 14979       http://dx.doi.org/10.1016/j.ijmm.2007.09.007
# 14980       http://dx.doi.org/10.1016/j.tifs.2009.04.005
# 14981   http://dx.doi.org/10.1016/j.ijnurstu.2012.11.006
# 14982  http://dx.doi.org/10.1016/j.antiviral.2013.06.009
# 14983  http://dx.doi.org/10.1016/B978-0-7020-4336-9.0...
# 14984        http://dx.doi.org/10.1016/j.dld.2014.09.018
# 14985       http://dx.doi.org/10.1016/j.yapd.2013.04.005
# 14986       http://dx.doi.org/10.1016/j.sram.2004.04.012
# 14987     http://dx.doi.org/10.1016/j.ejmech.2018.08.058
# 14988  http://dx.doi.org/10.1016/B978-008044910-4.003...
# 14989  http://dx.doi.org/10.1016/B978-1-4160-3429-2.0...
# 14990    http://dx.doi.org/10.1016/S0065-308X(01)50029-9
# 14991     http://dx.doi.org/10.1016/0042-6822(91)90795-D
# 14992       http://dx.doi.org/10.1016/j.jhin.2018.07.047
# 14993        http://dx.doi.org/10.1016/j.jep.2015.07.015
# 14994  http://dx.doi.org/10.1016/B978-0-08-045359-0.5...
# 14995        http://dx.doi.org/10.1007/s12014-010-9058-8
# 14996       http://dx.doi.org/10.1016/j.jmii.2016.04.003
# 14997       http://dx.doi.org/10.1016/j.jdds.2016.08.004
# 14998     http://dx.doi.org/10.1016/0306-9877(87)90024-7
# 14999    http://dx.doi.org/10.1016/S0755-4982(06)74709-1
#
#                                                    title  \
# 0      The RNA pseudoknots in foot-and-mouth disease ...
# 1      Healthcare-resource-adjusted vulnerabilities t...
# 2      Real-time, MinION-based, amplicon sequencing f...
# 3      A Combined Evidence Approach to Prioritize Nip...
# 4      Assessing spread risk of Wuhan novel coronavir...
# 5      TWIRLS, an automated topic-wise inference meth...
# 6      Viruses are a dominant driver of protein adapt...
# 7      The impact of regular school closure on season...
# 8      Carbon Nanocarriers Deliver siRNA to Intact Pl...
# 9      Protective Population Behavior Change in Outbr...
# 10     A hidden gene in astroviruses encodes a cell-p...
# 11     Live-cell single RNA imaging reveals bursts of...
# 12     Development and Evaluation of A CRISPR-based D...
# 13     Estimation of the final size of the second pha...
# 14     Self-assembly of the RZZ complex into filament...
# 15     Development of CRISPR as a prophylactic strate...
# 16     A spatial model of CoVID-19 transmission in En...
# 17        TALC: Transcription-Aware Long Read Correction
# 18     Nelfinavir was predicted to be a potential inh...
# 19     Beyond R0: the importance of contact tracing w...
# 20     Multiple approaches for massively parallel seq...
# 21     The 2019 coronavirus (SARS-CoV-2) surface prot...
# 22     International travelers and genomics uncover a...
# 23     Complemented palindrome small RNAs first disco...
# 24     Quantifying the success of measles vaccination...
# 25     Epidemiological characteristics of 1212 COVID-...
# 26     Cryo-EM structures of HKU2 and SADS-CoV spike ...
# 27     Mono-ADP-ribosylation by ARTD10 restricts Chik...
# 28     The influenza A virus endoribonuclease PA-X us...
# 29     Artesunate interacts with Vitamin D receptor t...
# ...                                                  ...
# 14970  The human gut microbiota and virome: Potential...
# 14971  Geospatial distribution of viromes in tropical...
# 14972  Intranasal fluticasone propionate does not pre...
# 14973  A new membrane based process to isolate immuno...
# 14974             8 Mechanisms of Cell and Tissue Damage
# 14975  Antiviral Decoction of Isatidis Radix (板藍根 bǎn...
# 14976  A novel method for making human monoclonal ant...
# 14977  Clinical imaging research of the first Middle ...
# 14978  Rapid detection and identification of 12 respi...
# 14979  Bacillus anthracis: Balancing innocent researc...
# 14980  Revisiting the melamine contamination event in...
# 14981  50th Anniversary Editorial: Building on firm f...
# 14982  Chikungunya fever: Epidemiology, clinical synd...
# 14983                                   Chapter 48 Heart
# 14984  Human rhinovirus infection and cirrhosis: A po...
# 14985  Slums Are Not Places for Children to Live Vuln...
# 14986  Biochemical terrorism: the medical threat in t...
# 14987  Structure-activity relationship studies of lip...
# 14988            Communicable Diseases, Globalization of
# 14989          Chapter 10 Liver and Bile Duct Infections
# 14990  The malaria-infected red blood cell: Structura...
# 14991  Random nature of coronavirus RNA recombination...
# 14992  What are the main drivers for public policies ...
# 14993  Houttuynia cordata Thunb. polysaccharides amel...
# 14994  Chapter 38 As Travel Medicine Practitioner dur...
# 14995  Urine Peptidomic and Targeted Plasma Protein A...
# 14996  Toward sustainable and effective control: Expe...
# 14997  Acute Hemorrhagic Edema with extensive truck i...
# 14998  Was a neurovirulent influenza virus the cause ...
# 14999    Orientation diagnostique devant une lymphopénie
#
#                                                  authors  year  cluster  \
# 0      Ward, J. C. J.; Lasecka-Dykes, L.; Neil, C.; A...  2020        2
# 1      Hanchu Zhou; Jianan Yang; Kaichen Tang; Qingpe...  2020        7
# 2      Butt, S. L.; Erwood, E. C.; Zhang, J.; Sellers...  2019        4
# 3      Nishi Kumari; Ayush Upadhyay; Kishan Kalia; Ra...  2020        5
# 4      Shengjie Lai; Isaac Bogoch; Nick Ruktanonchai;...  2020        2
# 5      Xiaoyang Ji; Chunming Zhang; Yubo Zhai; Zhongh...  2020        2
# 6      David Enard;Le Cai;Carina Gwenapp;Dmitri A Pet...  2015        2
# 7      De Luca, G.; Van Kerckhove, K.; Coletti, P.; P...  2017        8
# 8      Demirer, G. S.; Zhang, H.; Goh, N. S.; Pinals,...  2019        5
# 9              Lodge, E. K.; Schatz, A. M.; Drake, J. M.  2020        2
# 10                               Lulla, V.; Firth, A. E.  2019        5
# 11     Lyon, K. R.; Aguilera, L. U.; Morisaki, T.; Mu...  2018        5
# 12     Tieying Hou; Weiqi Zeng; Minling Yang; Wenjing...  2020        2
# 13                                         milan batista  2020        2
# 14     Gassmann, R.; Pereira, C.; Reis, R. M.; Gama, ...  2018        5
# 15     Timothy R. Abbott; Girija Dhamdhere; Yanxia Li...  2020        2
# 16     Leon Danon; Ellen Brooks-Pollock; Mick Bailey;...  2020        2
# 17     Broseus, L.; Thomas, A.; Oldfield, A.; Sevrac,...  2020        8
# 18     Xu, Z.; Peng, C.; Shi, Y.; Zhu, Z.; Mu, K.; Wa...  2020        2
# 19     Laurent Hébert-Dufresne; Benjamin M. Althouse;...  2020        8
# 20     Minfeng Xiao; Xiaoqing Liu; Jingkai Ji; Min Li...  2020        2
# 21     Mycroft-West, C. J.; Su, D.; Elli, S.; Guimond...  2020        2
# 22     Grubaugh, N.; Saraf, S.; Gangavarapu, K.; Watt...  2018        8
# 23     Liu, C.; Chen, Z.; Shen, W.; Yu, D.; Li, S.; H...  2017        2
# 24     Taylor Chin; Caroline O. Buckee; Ayesha S. Mahmud  2019        2
# 25     Pei Wang; Junan Lu; Yanyu Jin; Mengfan Zhu; Li...  2020        2
# 26                   Yu, J.; Qiao, S.; Guo, R.; Wang, X.  2020        2
# 27     Krieg, S.; Pott, F.; Eckei, L.; Verheirstaeten...  2020        2
# 28     Gaucherand, L.; Porter, B. K.; Schmaling, S. K...  2018        2
# 29     Shang, S.; Wu, J.; Li, X.; Liu, X.; Li, P.; Zh...  2020        6
# ...                                                  ...   ...      ...
# 14970  Scarpellini, Emidio; Ianiro, Gianluca; Attili,...  2015        9
# 14971  Gu, Xiaoqiong; Tay, Qi Xiang Martin; Te, Shu H...  2018        4
# 14972  Ruohola, Aino; Heikkinen, Terho; Waris, Matti;...  2000        1
# 14973  Liu, Jianguo; Yang, Juan; Xu, Hai; Lu, Junren;...  2010        5
# 14974      Mims, Cedric A.; Nash, Anthony; Stephen, John  2001        0
# 14975  Ke, Lijing; Wen, Teng; Bradshaw, Jeremy P.; Zh...  2012        6
# 14976  Fraussen, J.; Vrolix, K.; Martinez-Martinez, P...  2010        6
# 14977  Lan, Bowen; Lu, Puxuan; Zeng, Yujing; Li, Xin;...  2015        1
# 14978        Kim, Suk Ran; Ki, Chang-Seok; Lee, Nam Yong  2009        1
# 14979  Hudson, Michael J.; Beyer, Wolfgang; Böhm, Rei...  2008        0
# 14980                   Chan, Zenobia C.Y.; Lai, Wing-Fu  2009        7
# 14981                      Norman, Ian; Griffiths, Peter  2013        7
# 14982  Thiberville, Simon-Djamel; Moyen, Nanikaly; Du...  2013        0
# 14983                                         Burrow, R.  2014        9
# 14984  Jacques, Jérémie; Carrier, Paul; Legros, Romai...  2015        9
# 14985  Ernst, Kacey C.; Phillips, Beth S.; Duncan, Bu...  2013        7
# 14986  Laish, Ido; Maman, Maor; Marcus, Nir; Rotman, ...  2004        7
# 14987  Szűcs, Zsolt; Kelemen, Viktor; Le Thai, Son; C...  2018        5
# 14988                                       Oppong, J.R.  2009        7
# 14989                                   Misdraji, Joseph  2010        9
# 14990  Cooke, Brian M.; Mohandas, Narla; Coppel, Ross L.  2001        0
# 14991                   Banner, Lisa R.; Mc Lai, Michael  1991        4
# 14992  Padoveze, M.C.; Nogueira-Jr, C.; Tanner, J.; T...  2019        7
# 14993  Xu, Yan-Yan; Zhang, Yun-Yi; Ou, Ying-Ye; Lu, X...  2015        6
# 14994                             Wilder-Smith, Annelies  2007        7
# 14995  Ling, Xuefeng B.; Lau, Kenneth; Deshpande, Che...  2010        5
# 14996  Luo, Yang; Song, Caiping; Zhang, Hongyan; Wang...  2017        7
# 14997                  Al Murayshid, Abdurrahman Ibrahim  2017        9
# 14998                                      Maurizi, C.P.  1987        9
# 14999  Berezné, Alice; Bono, Wafaa; Guillevin, Loïc; ...  2006        3
#
#                                 label_corresponding_name
# 0      ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 1      ['respondent', 'political', 'sector', 'profess...
# 2      ['amplicon', 'accession', 'primer', 'sequencin...
# 3      ['pdb', 'hydrophobic', 'spectra', 'solvent', '...
# 4      ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 5      ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 6      ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 7      ['assume', 'parameter', 'simulate', 'assumptio...
# 8      ['pdb', 'hydrophobic', 'spectra', 'solvent', '...
# 9      ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 10     ['pdb', 'hydrophobic', 'spectra', 'solvent', '...
# 11     ['pdb', 'hydrophobic', 'spectra', 'solvent', '...
# 12     ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 13     ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 14     ['pdb', 'hydrophobic', 'spectra', 'solvent', '...
# 15     ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 16     ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 17     ['assume', 'parameter', 'simulate', 'assumptio...
# 18     ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 19     ['assume', 'parameter', 'simulate', 'assumptio...
# 20     ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 21     ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 22     ['assume', 'parameter', 'simulate', 'assumptio...
# 23     ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 24     ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 25     ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 26     ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 27     ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 28     ['biorxiv', '2020', 'peer', 'perpetuity', 'med...
# 29     ['blot', 'fbs', 'sigma', 'wash', 'dmem', 'tran...
# ...                                                  ...
# 14970  ['diarrhoea', 'spp', 'biopsy', 'abdominal', 'k...
# 14971  ['amplicon', 'accession', 'primer', 'sequencin...
# 14972  ['ari', 'metapneumovirus', 'hospitalization', ...
# 14973  ['pdb', 'hydrophobic', 'spectra', 'solvent', '...
# 14974  ['apoptosis', 'ifn', 'dcs', 'signaling', 'kina...
# 14975  ['blot', 'fbs', 'sigma', 'wash', 'dmem', 'tran...
# 14976  ['blot', 'fbs', 'sigma', 'wash', 'dmem', 'tran...
# 14977  ['ari', 'metapneumovirus', 'hospitalization', ...
# 14978  ['ari', 'metapneumovirus', 'hospitalization', ...
# 14979  ['apoptosis', 'ifn', 'dcs', 'signaling', 'kina...
# 14980  ['respondent', 'political', 'sector', 'profess...
# 14981  ['respondent', 'political', 'sector', 'profess...
# 14982  ['apoptosis', 'ifn', 'dcs', 'signaling', 'kina...
# 14983  ['diarrhoea', 'spp', 'biopsy', 'abdominal', 'k...
# 14984  ['diarrhoea', 'spp', 'biopsy', 'abdominal', 'k...
# 14985  ['respondent', 'political', 'sector', 'profess...
# 14986  ['respondent', 'political', 'sector', 'profess...
# 14987  ['pdb', 'hydrophobic', 'spectra', 'solvent', '...
# 14988  ['respondent', 'political', 'sector', 'profess...
# 14989  ['diarrhoea', 'spp', 'biopsy', 'abdominal', 'k...
# 14990  ['apoptosis', 'ifn', 'dcs', 'signaling', 'kina...
# 14991  ['amplicon', 'accession', 'primer', 'sequencin...
# 14992  ['respondent', 'political', 'sector', 'profess...
# 14993  ['blot', 'fbs', 'sigma', 'wash', 'dmem', 'tran...
# 14994  ['respondent', 'political', 'sector', 'profess...
# 14995  ['pdb', 'hydrophobic', 'spectra', 'solvent', '...
# 14996  ['respondent', 'political', 'sector', 'profess...
# 14997  ['diarrhoea', 'spp', 'biopsy', 'abdominal', 'k...
# 14998  ['diarrhoea', 'spp', 'biopsy', 'abdominal', 'k...
# 14999  ['en', 'dans', 'como', 'sont', 'les', 'por', '...
#
# [15000 rows x 8 columns]

# %% [markdown]
# # Exporting the results / Dashboarding:

# %% [markdown]
# https://dash.plotly.com/dash-core-components/dropdown

# %% [markdown]
# http://holoviews.org/user_guide/Deploying_Bokeh_Apps.html

# %% [markdown]
# https://realpython.com/python-data-visualization-bokeh/
